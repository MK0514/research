# %% [markdown]
# <a href="https://colab.research.google.com/github/MK0514/research/blob/main/test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 압축 파일 이름이 rocket_sim.zip인 경우
# !unzip rocket_sim_suite.zip -d rocket_sim_project

# 작업 디렉토리를 압축 푼 폴더로 이동 (매우 중요)
# %cd rocket_sim_project
# Out:
# Archive:  rocket_sim_suite.zip
#    creating: rocket_sim_project/rocket_sim/
#   inflating: rocket_sim_project/rocket_sim/main.py
#    creating: rocket_sim_project/rocket_sim/visualization/
#  extracting: rocket_sim_project/rocket_sim/visualization/__init__.py
#    creating: rocket_sim_project/rocket_sim/optimization/
#  extracting: rocket_sim_project/rocket_sim/optimization/__init__.py
#   inflating: rocket_sim_project/rocket_sim/README.md
#   inflating: rocket_sim_project/rocket_sim/requirements.txt
#    creating: rocket_sim_project/rocket_sim/{core,geometry,visualization,optimization,data}/
#    creating: rocket_sim_project/rocket_sim/core/
#    creating: rocket_sim_project/rocket_sim/core/__pycache__/
#   inflating: rocket_sim_project/rocket_sim/core/__pycache__/aerodynamics.cpython-312.pyc
#   inflating: rocket_sim_project/rocket_sim/core/__pycache__/__init__.cpython-312.pyc
#   inflating: rocket_sim_project/rocket_sim/core/__pycache__/atmosphere.cpython-312.pyc
# ...

# %%
# !python rocket_sim/main.py
# Out:
# ...
#    우주발사체 공기역학 시뮬레이션 Suite
#    Launch Vehicle Aerodynamic Analysis Suite
#    ISA 대기 모델 기반 | 충격파·팽창파·항력 해석
# ...
#
# [분석 중] Generic Launch Vehicle
# === Generic Launch Vehicle ===
#   전체 길이    : 57.00 m
#   최대 직경    : 1.850 m
#   세장비 (L/D) : 30.81
#   두부 반각    : 7.32°
#   전면 면적    : 2.6880 m²
#   습윤 면적    : 295.94 m²
#   체적         : 124.21 m³
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:1245: RuntimeWarning: divide by zero encountered in divide
#   a = -(dx2)/(dx1 * (dx1 + dx2))
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:1246: RuntimeWarning: divide by zero encountered in divide
#   b = (dx2 - dx1) / (dx1 * dx2)
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:1247: RuntimeWarning: divide by zero encountered in divide
#   c = dx1 / (dx2 * (dx1 + dx2))
# /usr/local/lib/python3.12/dist-packages/numpy/lib/_function_base_impl.py:1253: RuntimeWarning: invalid value encountered in add
# ...
